# %%
#importing needed libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("covid_deaths_usafacts.csv")
temp = df.columns.values
for i in range(len(temp)-1, 5, -1):
    df[temp[i]] = df[temp[i]] - df[temp[i-1]]


#df.to_csv(r'C:\Users\Tanya Kejriwal\DATATHON\covid_death_modified.csv', header=True, index= False )
# Out:
# 269

# %%
df = pd.read_csv('covid_confirmed_modified.csv')
is_tx = df['State'] == 'TX'
df2 = df[is_tx]
df3 = df2.drop(columns = [temp[0], temp[1], temp[2], temp[3]])
arr = df3.to_numpy()
ticks = np.arange(start=1, stop=270, step=1)
print(len(arr[21]))
print(max(arr[21]))
#arr[1]
plt.plot(arr[21])
#plt.xticks(ticks, temp[4:])

plt.show()
# Out:
# 269
# 145

# %%
print(np.amax(arr))
# Out:
# 14129
